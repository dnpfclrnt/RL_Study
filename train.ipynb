# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

learning_rate = 0.0002
gamma = 0.98
n_rollout = 10

# %%
class ActorCritic(nn.Module):
    def __init__(self, n_observation: int, n_actions: int, lr: float) -> None:
        super(ActorCritic, self).__init__()
        self.data = []
        self.n_obs = n_observation
        self.n_act = n_actions
        self.lr = lr

        self.fc1 = nn.Linear(self.n_obs, 256)
        self.fc_policy = nn.Linear(256, 2)
        self.fc_value = nn.Linear(256, 1)
        self.optim = optim.Adam(self.parameters(), lr=self.lr)

    def policy_net(self, x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.fc_policy(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    def value_net(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_value(x)
        return v
    
    def put_data(self, transition):
        self.data.append(transition)

    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, done_lst = [], [], [], [], []
        for transition in self.data:
            s, a, r, s_prime, done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r/100.0])
            s_prime_lst.append(s_prime)
            done_mask = 0.0 if done else 1.0
            done_lst.append([done_mask])
        s_batch, a_batch, r_batch, s_prime_batch, done_batch = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                                               torch.tensor(r_lst, dtype=torch.float), torch.tensor(s_prime_lst, dtype=torch.float), \
                                                               torch.tensor(done_lst, dtype=torch.float)
        self.data = []
        return s_batch, a_batch, r_batch, s_prime_batch, done_batch
    
    def train_net(self):
        s, a, r, s_prime, done = self.make_batch()
        td_target = r + gamma * self.value_net(s_prime) * done
        delta = td_target - self.value_net(s)

        pi = self.policy_net(s, softmax_dim=1)
        pi_a = pi.gather(1, a)
        loss = -torch.log(pi_a) * delta.detach() + F.smooth_l1_loss(self.value_net(s), td_target.detach())

        self.optim.zero_grad()
        loss.mean().backward()
        self.optim.step()

# %%
env = gym.make('CartPole-v1', render_mode="rgb_array")
state = env.reset()
n_actions = env.action_space.n
n_observation = state[0].shape[0]
model = ActorCritic(n_observation=n_observation, n_actions=n_actions, lr=learning_rate)
print_interval = 20
score = 0.0

for episode in range(6000):
    count = 0
    terminated = False
    state = env.reset()[0]
    while not terminated:
        for t in range(n_rollout):
            prob = model.policy_net(torch.from_numpy(state).float())
            m = Categorical(prob)
            action = m.sample().item()
            s_prime, r, terminated, _, info = env.step(action)
            count += 1
            model.put_data((state, action, r, s_prime, terminated))

            state = s_prime
            score += r
            if terminated:
                break
        model.train_net()
    if episode % print_interval == 0 and episode != 0:
        print(f"# episode : {episode}, avg score : {score/print_interval}, count : {count}")
        score = 0.0
env.close()
# Out:
# /opt/anaconda3/envs/rl/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# # episode : 20, avg score : 22.4, count : 15
# # episode : 40, avg score : 19.65, count : 19
# # episode : 60, avg score : 15.65, count : 17
# # episode : 80, avg score : 19.4, count : 19
# # episode : 100, avg score : 22.2, count : 22
# # episode : 120, avg score : 29.8, count : 13
# # episode : 140, avg score : 28.65, count : 22
# # episode : 160, avg score : 35.65, count : 35
# # episode : 180, avg score : 34.2, count : 16
# # episode : 200, avg score : 49.35, count : 20
# # episode : 220, avg score : 45.9, count : 30
# # episode : 240, avg score : 39.8, count : 77
# # episode : 260, avg score : 44.0, count : 68
# # episode : 280, avg score : 51.45, count : 48
# # episode : 300, avg score : 55.8, count : 53
# # episode : 320, avg score : 63.15, count : 97
# # episode : 340, avg score : 54.3, count : 92
# # episode : 360, avg score : 77.3, count : 44
# # episode : 4780, avg score : 144.7, count : 157
# # episode : 4800, avg score : 141.4, count : 134
# # episode : 4820, avg score : 131.45, count : 139
# # episode : 4840, avg score : 133.65, count : 132
# # episode : 4860, avg score : 132.9, count : 127
# # episode : 4880, avg score : 132.85, count : 137
# # episode : 4900, avg score : 133.5, count : 136
# # episode : 4920, avg score : 133.55, count : 135
# # episode : 4940, avg score : 131.95, count : 129
# # episode : 4960, avg score : 132.5, count : 124
# # episode : 4980, avg score : 126.9, count : 119
# # episode : 5000, avg score : 126.6, count : 131
# # episode : 5020, avg score : 127.4, count : 122
# # episode : 5040, avg score : 135.7, count : 139
# # episode : 5060, avg score : 147.45, count : 159
# # episode : 5080, avg score : 151.65, count : 162
# # episode : 5100, avg score : 164.15, count : 177
# # episode : 5120, avg score : 178.25, count : 202
# # episode : 5140, avg score : 218.35, count : 233
# # episode : 5160, avg score : 358.3, count : 365
# # episode : 5180, avg score : 501.6, count : 637
# # episode : 5200, avg score : 381.65, count : 198
# # episode : 5220, avg score : 219.7, count : 188
# # episode : 5240, avg score : 189.0, count : 147
# # episode : 5260, avg score : 166.4, count : 162
# # episode : 5280, avg score : 179.45, count : 155
# # episode : 5300, avg score : 202.75, count : 203
# # episode : 5320, avg score : 291.55, count : 232
# # episode : 5340, avg score : 190.65, count : 155
# # episode : 5360, avg score : 164.0, count : 146
# # episode : 5380, avg score : 142.2, count : 185
# # episode : 5400, avg score : 159.1, count : 171
# # episode : 5420, avg score : 143.8, count : 123
# # episode : 5440, avg score : 157.15, count : 183
# # episode : 5460, avg score : 163.65, count : 152
# # episode : 5480, avg score : 128.45, count : 137
# # episode : 5500, avg score : 147.15, count : 135
# # episode : 5520, avg score : 168.85, count : 157
# # episode : 5540, avg score : 165.35, count : 151
# # episode : 5560, avg score : 192.5, count : 210
# # episode : 5580, avg score : 236.25, count : 181
# # episode : 5600, avg score : 234.05, count : 251
# # episode : 5620, avg score : 270.3, count : 232
# # episode : 5640, avg score : 251.25, count : 168
# # episode : 5660, avg score : 247.9, count : 413
# # episode : 5680, avg score : 259.8, count : 160
# # episode : 5700, avg score : 192.9, count : 234
# # episode : 5720, avg score : 216.4, count : 236
# # episode : 5740, avg score : 246.4, count : 244
# # episode : 5760, avg score : 193.6, count : 167
# # episode : 5780, avg score : 188.85, count : 203
# # episode : 5800, avg score : 176.25, count : 195
# # episode : 5820, avg score : 239.6, count : 292
# # episode : 5840, avg score : 245.15, count : 193
# # episode : 5860, avg score : 249.9, count : 221
# # episode : 5880, avg score : 279.7, count : 358
# # episode : 5900, avg score : 286.05, count : 21
# # episode : 5920, avg score : 247.3, count : 208
# # episode : 5940, avg score : 209.05, count : 225
# # episode : 5960, avg score : 198.7, count : 191
# # episode : 5980, avg score : 208.35, count : 210

# %%
from PIL import Image
def show_gif(images: list) -> None:
    image_file = 'test.gif'
    images[0].save(image_file, save_all=True, append_images=images[1:], loop=0, duration=1)

state, _ = env.reset()
images = []

terminated = False
count = 0
while not terminated:
    screen = env.render()
    images += [Image.fromarray(screen)]
    for t in range(n_rollout):
        prob = model.policy_net(torch.from_numpy(state).float())
        m = Categorical(prob)
        a = m.sample().item()
        s_prime, r, terminated, truncated, info = env.step(a)
        count += 1
        state = s_prime

        if terminated:
            break
env.close()
print(count)
show_gif(images)
# Out:
# 335
